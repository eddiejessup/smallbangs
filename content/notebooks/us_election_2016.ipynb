# %% [markdown]
# # US 2016 Presidential Election
#
# Let's see which counties voted which way and why.
#
# ## Introduction
#
# During the presidential election campaign, I heard many predictions for how different people will vote. I heard that factors like a person's age, income, race and so on would correlate well with how they would vote. Frustratingly, these different predictions would usually only mention one or two of these possible variables, so I couldn't learn how people thought they compared with each other. I bet that whether or not someone prefers orangutans or gorillas has *some* predictive power for how that person will vote, but I think one could do better by inspecting something else.
#
# So I want to grab a bunch of demographic data, and the results of the election, and try to work out which information is the most useful in predicting how someone will vote. Later, I'd like to do this for other elections, to see how much of the *change* in election outcomes can be explained by *changes* in these demographic features.
#
# Everything I do here is measuring correlations. I don't know how direct the causality is between, for example, a person's income and their vote. It may be that income affects some other variable that I haven't got data on, like their preference to keep laws the same, and this may affect yet another variable, like their opinion on some policy, which eventually affects their vote. On the other hand, it could be that income more directly, causally affects someone's vote, and there are fewer causal links to follow. This analysis will not distinguish cases like these.
#
# As an aside, I don't think causality is a binary property of a pair of predictive and predicted variables. Outside of fundamental physics, few pairs of variables are directly causally linked. A predictive variable can be more or less strongly causally linked to some predicted variable, but to only say one is 'causal' of the other is not specific. I would prefer the saying to be re-phrased to something like 'correlation does not imply any degree of causation', to make clearer that even if any causation is present, this is a matter of degree, not of kind.

# %% [markdown]
# ## Load the labels: the presidential results
#
# Firstly, I want a data-set containing the voting outcomes. This will be the variable I try to predict, often called the 'label'. I can't get the vote per person, but I want the smallest voting unit possible, that I can also find good demographic data for. The best I can find is voting outcomes by county, which [Michael W. Kearney](https://github.com/mkearney) made available [here](https://github.com/mkearney/presidential_election_county_results_2016).

# %%
import pandas as pd
import numpy as np

# %%
import requests
from io import BytesIO

results_url = 'https://raw.githubusercontent.com/mkearney/presidential_election_county_results_2016/master/pres.elect16.results.wide.votes.dec9.csv'
results_response = requests.get(results_url)
# This BytesIO class lets me make a byte-string look like a file stream,
# which is what Pandas expects.
dp_raw = pd.read_csv(BytesIO(results_response.content))

# %% [markdown]
# A convenience of the US two-party dominance, is that a county's voting outcome can be represented quite well by one number: the difference between the vote share of the Democrat and Republican candidates. This number is the label I will try to predict. More specifically, the label I use is,
#
# <div style="margin-top: 1em;">
# $$\text{Democrat advantage} := \left( \text{Democrat votes} - \text{Republican votes} \right)\  / \ \text{Total votes} \; .$$
# </div>
#
# The analysis and outcome would be the same if the reverse definition, the 'Republican advantage', were used. This number ranges from -1, or -100%, if all votes are for the Republican candidate, to 0, or 0%, if both dominant parties receive equal votes, to 1, or 100%, if all votes are for the Democrat candidate.

# %%
# Remove rows that aren't at a per-county level (like per-state and per-country)
dp = dp_raw[dp_raw.county.notnull()].copy()
# Cast the country identifier to an int so we can join to features correctly later.
dp.loc[:, 'fips'] = dp.fips.astype(int)
# Compute the difference in vote share, which will be our target label.
dp['dem_adv'] = (dp['Hillary Clinton'] - dp['Donald Trump']) / dp['total_votes']
# Remove extra information I don't need.
dp = dp.loc[:, ('county', 'fips', 'dem_adv', 'total_votes')]

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.charts import Bar, Scatter, Histogram, Line
from bokeh.palettes import brewer
from bokeh.models import FuncTickFormatter

palette = brewer['Set3'][12]
output_notebook(hide_banner=True)

# %% [markdown]
# Let's look at how this number is distributed across counties. All plots here are made using [Bokeh](http://bokeh.pydata.org), a fantastic plotting library for Python. The plots are interactive, so you can pan and zoom around as you like.

# %%
show(Histogram(100 * dp['dem_adv'],
               legend=False, palette=palette,
               ylabel='Number of counties',
               xlabel='(Democrat vote share - Republican vote share) / percent',
               title='Distribution of county vote share'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b784485b-4041-4a84-b403-42ff0d2a05dc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b784485b-4041-4a84-b403-42ff0d2a05dc").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b784485b-4041-4a84-b403-42ff0d2a05dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b784485b-4041-4a84-b403-42ff0d2a05dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e5ff5bc1-0f7f-4928-b3dd-b9ed591ca619":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"593fc866-a489-40f0-b0d6-6116fbb052e7","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(14.458277, 19.763009]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[51.0],"label":["(14.458277, 19.763009]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.304732011286831],"x":["17.110643"],"y":[25.5]}},"id":"d148bef6-fb8a-4722-b011-6a9d3cbf49e3","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d9f19b5c-78e6-4f0e-aee8-72506687efb7","type":"Rect"},{"attributes":{"data_source":{"id":"86ed2ccb-1115-47a3-beae-9c43da1960c5","type":"ColumnDataSource"},"glyph":{"id":"f093360e-e043-460b-bedf-98aea1eea25d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"cae50cfb-a1bf-498a-bf18-039b07da90b4","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"78a3dcfc-c56d-47e8-825d-c1dc60c51c75","type":"ColumnDataSource"},"glyph":{"id":"8c194f59-1381-4e2e-81a1-dbe0126a0ead","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"1bc91a2b-b2e7-4dac-833c-2b15d2d61026","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-33.284312, -27.979580]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[174.0],"label":["(-33.284312, -27.979580]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.3047320112868235],"x":["-30.631946"],"y":[87.0]}},"id":"24c7ad39-1258-4048-80cb-675f146eaaa7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(19.763009, 25.067741]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[45.0],"label":["(19.763009, 25.067741]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.304732011286816],"x":["22.415375"],"y":[22.5]}},"id":"f8320093-536e-494d-b620-83918e3b9ab7","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-54.503240, -49.198508]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[286.0],"label":["(-54.503240, -49.198508]"],"line_alpha":[1.0],"line_color":["black"],"width":[5.3047320112868235],"x":["-51.850874"],"y":[143.0]}},"id":"d73c9b1b-6b51-4158-9684-aac3cf59bcbd","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"d73c9b1b-6b51-4158-9684-aac3cf59bcbd","type":"ColumnDataSource"},"glyph":{"id":"593fc866-a489-40f0-b0d6-6116fbb052e7","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5989be2e-f9a7-4b3d-ac1d-9df0b165216d","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e31dadd-87d2-4515-b434-3dd73b124d3d","type":"Rect"},{"attributes":{"data_source":{"id":"d148bef6-fb8a-4722-b011-6a9d3cbf49e3","type":"ColumnDataSource"},"glyph":{"id":"3e31dadd-87d2-4515-b434-3dd73b124d3d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"29f30175-872c-4c8b-8814-ecd96a8d054f","type":"GlyphRenderer"},{"attributes":{"cal ...

# %% [markdown]
# It looks like there's a large bias towards the Republican candidate, more than one might expect, knowing that the overall vote was quite close. But this is because people from counties with smaller populations are more likely to vote Republican, so although there are more counties with a Republican majority, they contribute less to the national vote count, to the extent that in fact the total number of Democrat votes was higher. (This wasn't reflected in who was elected President because of how the Electoral college works.)

# %%
dtmp = dp.copy()
dtmp['logvotes'] = np.log10(dtmp['total_votes'])
dtmp['dem_adv_pc'] = 100 * dtmp['dem_adv']
p = Scatter(dtmp, x='logvotes', y='dem_adv_pc',
            legend=False, palette=palette,
            title='Approximate correlation of vote share with county population',
            xlabel='Total votes (rough proxy for population)',
            ylabel='Excess democrat vote share / percent',
            )
p.xaxis.formatter = FuncTickFormatter(code='return "10^" + tick')
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fa6bb23e-1454-4da9-9d13-078871488982"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fa6bb23e-1454-4da9-9d13-078871488982").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fa6bb23e-1454-4da9-9d13-078871488982");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fa6bb23e-1454-4da9-9d13-078871488982' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"404ce839-c49c-461d-8cae-5b2e7010300b":{"roots":{"references":[{"attributes":{},"id":"4956a278-cd1c-4df3-9273-ca6875e73786","type":"BasicTicker"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"704f6114-b157-43db-9413-5ba6a7581d21","type":"Circle"},{"attributes":{},"id":"7dbab291-9571-430c-b87b-59d60a3062cc","type":"BasicTicker"},{"attributes":{},"id":"2fac4d24-1a23-4319-80ec-528b89485b03","type":"ToolEvents"},{"attributes":{"callback":null,"end":6.8853258440120175,"start":1.3444394403449662},"id":"bb58659b-bf47-4ff2-9385-e6319c2e828d","type":"Range1d"},{"attributes":{},"id":"b3d2f34b-3d73-40d6-b6ba-6f15e203a190","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"}},"id":"a76dfe7c-ec2b-448c-b608-0246be90e218","type":"HelpTool"},{"attributes":{"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"}},"id":"1a52e759-85f4-4ab9-a295-bfedc03d4bf3","type":"PanTool"},{"attributes":{"overlay":{"id":"2d64dd76-38cf-469b-b2ef-a13adbe15846","type":"BoxAnnotation"},"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"}},"id":"68419056-9870-4f39-b50a-9d706f75b3d8","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"}},"id":"fa2fc2d9-39e5-4f0b-95b1-58c581670445","type":"SaveTool"},{"attributes":{"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"},"ticker":{"id":"7dbab291-9571-430c-b87b-59d60a3062cc","type":"BasicTicker"}},"id":"4e0e716a-bd88-48bf-848e-6245366f5735","type":"Grid"},{"attributes":{"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"}},"id":"cb91cfe9-9ac1-499b-ac33-a0e8cb1804fb","type":"ResetTool"},{"attributes":{"plot":null,"text":"Approximate correlation of vote share with county population"},"id":"7a77da3f-350d-4006-9205-9bcccc207691","type":"Title"},{"attributes":{"data_source":{"id":"ad10f94f-01f7-4f2a-8760-5c9fe6219526","type":"ColumnDataSource"},"glyph":{"id":"704f6114-b157-43db-9413-5ba6a7581d21","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"6f6b440d-a4dc-46be-9259-3419ceb4986e","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"}},"id":"57ee1079-103f-4cb5-b28f-0b674fd414d2","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"746a7839-dd32-4a11-8ec9-9c2298903c81","subtype":"Chart","type":"Plot"},"ticker":{"id":"4956a278-cd1c-4df3-9273-ca6875e73786","type":"BasicTicker"}},"id":"99d3309e-7629-4cd2-874c-2da725f92d4c","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"1a52e759-85f4-4ab9-a295-bfedc03d4bf3","type":"PanTool"},{"id":"57ee1079-103f-4cb5-b28f-0b674fd414d2","type":"WheelZoomTool"},{"id":"68419056-9870-4f39-b50a-9d706f75b3d8","type":"BoxZoomTool"},{"id":"fa2fc2d9-39e5-4f0b-95b1-58c581670445","type":"SaveTool"},{"id":"cb91cfe9-9ac1-499b-ac33-a0e8cb1804fb","type":"ResetTool"},{"id":"a76dfe7c-ec2b-448c-b608-0246be90e218","type":"HelpTool"}]},"id":"d53d38af-c74a-4f3e-8d0c-a5d9a2beb8f7","type":"Toolbar"},{"attributes":{"below":[{"id":"3afa6f81-d69c-4610-b3af-eda0cee87e6a","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"0549ac91-6570-476a-b6ef-da9ba4730daf","type":"LinearAxis"}],"renderers":[{"id":"2d64dd76-38cf-469b-b2ef-a13adbe15846","type":"BoxAnnotation"},{"id":"6f6b440d-a4dc-46be-9259-3419ceb4986e","type":"GlyphRenderer"},{"id":"3afa6f81-d69c-4610-b3af-eda0cee87e6a","type":"LinearAxis"},{"id":"0549ac91-6570-476a-b6ef-da9ba4730daf","type":"LinearAxis"},{"id":"4e0e716a-bd88-48bf-848e-6245366f5735","type":"Grid"},{"id":"99d3309e-7629-4cd2-874c-2da725f92d4c","type":"Grid"}],"title":{"id ...

# %% [markdown]
# ## Load the features: demographic data
#
# Now that I have a target number associated with each county, I need some attributes of these counties, so that I can build a model to predict this target. Even though I won't actually use this model to predict anything, I can inspect the trained model to analyse what features are important in predicting how a county votes.
#
# I got this data from a Kaggle competition page, which aggregates data from the US Census Bureau. If you want to run this notebook yourself, you'll have to get the file, `county_facts.csv`, from the [Kaggle page](https://www.kaggle.com/benhamner/2016-us-election/) yourself, because Kaggle requires authentication before you can download the file, so I can't just fetch from a URL.

# %%
dcf = pd.read_csv('county_facts.csv')
# Remove data not at the per-county level.
dcf = dcf[dcf.state_abbreviation.notnull()]
# Remove extra information I don't need.
# dcf = dcf.drop('state_abbreviation', axis=1)

# %% [markdown]
# The table's columns are named according to some coding scheme, which doesn't make much sense to humans. There's another table where human-readable names for these codes can be looked up, which is also on the Kaggle page, called `county_facts_dictionary.csv`. These names are actually a bit *too* verbose to use as column names though, so I renamed the columns myself, to something in the middle: meaningful, but short.

# %%
# Rename the columns to make more sense.
dcf = dcf.rename(columns={
    'PST045214': 'people_2014',
    'PST040210': 'people_2010',
    'PST120214': 'people_percent_change',
    'POP010210': 'people_2010_two',
    'AGE135214': 'percent_people_under_5',
    'AGE295214': 'percent_people_under_18',
    'AGE775214': 'percent_people_over_65',
    'SEX255214': 'percent_people_female',
    'RHI125214': 'percent_people_white_only',
    'RHI225214': 'percent_people_black_only',
    'RHI325214': 'percent_people_native_mainland',
    'RHI425214': 'percent_people_asian_only',
    'RHI525214': 'percent_people_native_pacific',
    'RHI625214': 'percent_people_multiple_race',
    'RHI725214': 'percent_people_hispanic',
    'RHI825214': 'percent_people_white_non_hispanic',
    'POP715213': 'percent_people_living_in_same_house',
    'POP645213': 'percent_people_foreign_born',
    'POP815213': 'percent_people_non_english_at_home',
    'EDU635213': 'percent_people_high_school_graduate',
    'EDU685213': 'percent_people_bachelors',
    'VET605213': 'veterans',
    'LFE305213': 'mean_commute_time_minutes',
    'HSG010214': 'housing_units',
    'HSG445213': 'home_ownership_rate',
    'HSG096213': 'percent_housing_units_in_multi_unit_structures',
    'HSG495213': 'median_value_owner_occupied_housing_units',
    'HSD410213': 'households',
    'HSD310213': 'people_per_household',
    'INC910213': 'money_income_per_capita',
    'INC110213': 'median_household_income',
    'PVY020213': 'percent_people_in_poverty',
    'BZA010213': 'private_nonfarm_places',
    'BZA110213': 'private_nonfarm_employment',
    'BZA115213': 'private_nonfarm_employment_percent_change',
    'NES010213': 'nonemployer_places',
    'SBO001207': 'number_firms',
    'SBO315207': 'percent_firms_black_owned',
    'SBO115207': 'percent_firms_native_mainland_owned',
    'SBO215207': 'percent_firms_asian_owned',
    'SBO515207': 'percent_firms_pacific_owned',
    'SBO415207': 'percent_firms_hispanic_owned',
    'SBO015207': 'percent_firms_women_owned',
    'MAN450207': 'manufacturer_shipments_thousands',
    'WTN220207': 'merchant_wholesaler_sales_thousands',
    'RTN130207': 'retail_sales_thousands',
    'RTN131207': 'retail_sales_per_capita',
    'AFN120207': 'accommodation_and_food_services_sales_thousands',
    'BPS030214': 'building_permits',
    'LND110210': 'land_area_square_miles',
    'POP060210': 'people_per_square_mile',
})

# %% [markdown]
# ## Combine the features with the labels

# %% [markdown]
# Now we need to merge the labels and features together. Each county has a unique '[FIPS](https://www.wikiwand.com/en/Federal_Information_Processing_Standards) County Code', that is present in both datasets, that I can use to join them.

# %%
# Merge the feature and label data, as an outer join so we can inspect the missing rows.
# An outer join means any rows in either table that don't exist in the other will be kept.
dcfp = dcf.merge(dp, on='fips', how='outer').drop('fips', axis=1)

# %%
# Count the counties that are missing in the feature data.
len(dcfp[dcfp.area_name.isnull()])
# Out:
# 0

# %%
# Count the counties that are missing in the label data.
len(dcfp[dcfp.county.isnull()])
# Out:
# 32

# %% [markdown]
# There are 32 rows in the demographic data that aren't in the voting data. Let's see which,

# %%
dcfp[dcfp.county.isnull()].loc[:, ('area_name', 'state_abbreviation')]
# Out:
#                               area_name state_abbreviation
# 67               Aleutians East Borough                 AK
# 68           Aleutians West Census Area                 AK
# 69               Anchorage Municipality                 AK
# 70                   Bethel Census Area                 AK
# 71                  Bristol Bay Borough                 AK
# 72                       Denali Borough                 AK
# 73               Dillingham Census Area                 AK
# 74         Fairbanks North Star Borough                 AK
# 75                       Haines Borough                 AK
# 76            Hoonah-Angoon Census Area                 AK
# 77              Juneau City and Borough                 AK
# 78              Kenai Peninsula Borough                 AK
# 79            Ketchikan Gateway Borough                 AK
# 80                Kodiak Island Borough                 AK
# 81           Lake and Peninsula Borough                 AK
# 82            Matanuska-Susitna Borough                 AK
# 83                     Nome Census Area                 AK
# 84                  North Slope Borough                 AK
# 85             Northwest Arctic Borough                 AK
# 86                   Petersburg Borough                 AK
# 87    Prince of Wales-Hyder Census Area                 AK
# 88               Sitka City and Borough                 AK
# 89                 Skagway Municipality                 AK
# 90      Southeast Fairbanks Census Area                 AK
# 91           Valdez-Cordova Census Area                 AK
# 92             Wade Hampton Census Area                 AK
# 93            Wrangell City and Borough                 AK
# 94             Yakutat City and Borough                 AK
# 95            Yukon-Koyukuk Census Area                 AK
# 548                      Kalawao County                 HI
# 2417                     Shannon County                 SD
# 2916                       Bedford city                 VA

# %% [markdown]
# 29 of the missing counties are in Alaska, with an extra three from Hawaii, South Dakota and Virginia. These are few enough, about 1% of the counties, that I'm just going to ignore them.

# %%
# Ignore the counties that are missing from the label data.
dcfp = dcfp[dcfp.county.notnull()]

# %% [markdown]
# As further validation, I'll check that the county names from both sets match (since I joined on the FIPS code, this need not be true).

# %%
# Find cases where the county names do not match between the two data-sets.
dcfp[dcfp.area_name != dcfp.county].loc[:, ('area_name', 'county')]
# Out:
#             area_name           county
# 1802  Do±a Ana County  Dona Ana County

# %% [markdown]
# There's a single mismatch, which is just a data entry mistake in the demographics table, so I can safely say that each row's data represents a single geographical area.

# %%
# Remove one of the duplicate columns containing the counties' names.
dcfp = dcfp.drop('area_name', axis=1)
dcfp = dcfp.drop(['state_abbreviation', 'total_votes'], axis=1)

# %% [markdown]
# ## Scale the features
#
# One last technical step before training the model, is to scale some of the demographic features so that the model can distinguish different scales easily. For example, county population spans many orders of magnitude,

# %%
from bokeh.models import FuncTickFormatter

# Ignore the one county with apparently zero population,
# to stop the logarithm operation breaking.
p = Histogram(np.log10(dcf['people_2014'][dcf['people_2014'] > 0]),
              legend=False, palette=palette,
              ylabel='Number of counties', xlabel='Population',
              title='Distribution of county populations')
# Format the x-axis tick labels as a power of ten.
p.xaxis.formatter = FuncTickFormatter(code='return "10^" + tick')

show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="83acad52-5c60-4fd8-a2ec-d1291d2287ee"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("83acad52-5c60-4fd8-a2ec-d1291d2287ee").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83acad52-5c60-4fd8-a2ec-d1291d2287ee");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83acad52-5c60-4fd8-a2ec-d1291d2287ee' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"791ce3b8-f99b-4cac-827c-283d776d9107":{"roots":{"references":[{"attributes":{"plot":{"id":"2edaa01a-e509-4ab0-b646-a05f9f435720","subtype":"Chart","type":"Plot"}},"id":"f5fa57df-b9be-4554-9e20-aa3d200282e0","type":"ResetTool"},{"attributes":{"plot":{"id":"2edaa01a-e509-4ab0-b646-a05f9f435720","subtype":"Chart","type":"Plot"}},"id":"25526ba0-2555-4f7e-95c0-fb67e08195a7","type":"SaveTool"},{"attributes":{"overlay":{"id":"c7770f12-48ae-4a8d-9b47-dee4f03ed4f8","type":"BoxAnnotation"},"plot":{"id":"2edaa01a-e509-4ab0-b646-a05f9f435720","subtype":"Chart","type":"Plot"}},"id":"99712e46-165f-4be4-9dcd-25b9f50ff2bc","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"c7770f12-48ae-4a8d-9b47-dee4f03ed4f8","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"2edaa01a-e509-4ab0-b646-a05f9f435720","subtype":"Chart","type":"Plot"}},"id":"a5a46e58-f1d8-4b53-9472-b4404180800a","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b3a718a8-1137-47ef-b6e9-ce0c7865bd6d","type":"PanTool"},{"id":"2d3f1685-2390-4ada-854b-e9d6f0eb3e08","type":"WheelZoomTool"},{"id":"99712e46-165f-4be4-9dcd-25b9f50ff2bc","type":"BoxZoomTool"},{"id":"25526ba0-2555-4f7e-95c0-fb67e08195a7","type":"SaveTool"},{"id":"f5fa57df-b9be-4554-9e20-aa3d200282e0","type":"ResetTool"},{"id":"a5a46e58-f1d8-4b53-9472-b4404180800a","type":"HelpTool"}]},"id":"389e4585-30d9-4abb-939e-ac71efe4081f","type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"14f55606-db2c-4653-854f-100eb3be89e4","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(6.371222, 6.476858]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[3.0],"label":["(6.371222, 6.476858]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.10563626323003739],"x":["6.42404"],"y":[1.5]}},"id":"e6a1f261-f47a-4be0-b7e4-e2019b08f967","type":"ColumnDataSource"},{"attributes":{"plot":null,"text":"Distribution of county populations"},"id":"174e95b8-c1a6-4557-bd3e-a2faa790eb9e","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(6.476858, 6.582494]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[2.0],"label":["(6.476858, 6.582494]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.10563626323003827],"x":["6.529676"],"y":[1.0]}},"id":"c32c6915-0c89-4e5a-ad2d-a9ecd164f163","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.673952, 2.779589]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[4.0],"label":["(2.673952, 2.779589]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.10563626323003783],"x":["2.7267704999999998"],"y":[2.0]}},"id":"c3b5a311-c53f-4679-a8f6-70a8fc4922c0","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.779589, 2.885225]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[13.0],"label":["(2.779589, 2.885225]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.10563626323003783],"x":["2.832407"],"y":[6.5]}},"id":"f3a5b14e-b278-4a00-9466-26cfa2a7e4f1","type":"ColumnDataSource"},{"attributes":{},"id":"d23b3b10-f50d-45e2-8773-3e1b1ee7798b"," ...

# %% [markdown]
# For the Random Forest model I use here, I don't need to scale features linearly, meaning that numbers that are distributed between zero and one hundred can stay as they are, they don't need to be scaled to lie between zero and one. But numbers that are distributed between one and ten million are typically very unevenly distributed on a linear scale, so putting them on a logarithmic scale makes it easier for the model to distinguish between different magnitudes of values.
#
# For the current data-set, this scaling is appropriate for raw counts of things like people, businesses and land area.

# %%
log_cols = (
    'people_2014',
    'people_2010',
    'people_2010_two',
    'veterans',
    'housing_units',
    'households',
    'nonemployer_places',
    'number_firms',
    'manufacturer_shipments_thousands',
    'merchant_wholesaler_sales_thousands',
    'retail_sales_thousands',
    'accommodation_and_food_services_sales_thousands',
    'building_permits',
    'land_area_square_miles',
)
dcfp_scaled = dcfp.copy()
for log_col in log_cols:
    # Replace each raw feature with a log-scaled equivalent.
    # Add one to each feature, because the numbers are never
    # small enough that this would matter,
    # but there are zeros, presumably for 'missing data', that would otherwise 
    # break the logarithm operation.
    dcfp_scaled.loc[:, '{}_log'.format(log_col)] = np.log10(dcfp[log_col] + 1)
    dcfp_scaled.drop(log_col, axis=1, inplace=True)

# %% [markdown]
# ## Train a model
#
# Finally I can train the model. I use [scikit-learn](http://scikit-learn.org), a popular machine learning library in the Python ecosystem. I've chosen to use a [Random Forest](https://www.wikiwand.com/en/Random_forest) regressor, as it allows ranking features by their predictive power, which is the point of this analysis.
#
# A simple linear regression would allow the same analysis, but it could not easily capture interactions between the different features, so it would explain less of the variation between counties, so I would have less confidence in its output. (I tested a linear regression and indeed the explained variance was significantly lower.)

# %%
from sklearn.ensemble import RandomForestRegressor

# Get the feature columns: all but the label and county name.
cols = [c for c in dcfp_scaled.columns
        if c not in ('county', 'dem_adv')]

# Shuffle the rows, to ensure the training and test data is similar.
inds = np.arange(len(dcfp))
rng = np.random.RandomState(seed=1)
rng.shuffle(inds)
dcfp_shuff = dcfp_scaled.iloc[inds]

X = dcfp_shuff.loc[:, cols].values
y = dcfp_shuff.loc[:, 'dem_adv'].values

# Split the data into training and test data.
i_split = int(round(4 * X.shape[0] / 5))
X_train, X_test = X[:i_split], X[i_split:]
y_train, y_test = y[:i_split], y[i_split:]

# Specify the model.
regr = RandomForestRegressor(n_estimators=50, n_jobs=3, random_state=rng)

# Train the model.
regr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=50, n_jobs=3, oob_score=False,
#            random_state=<mtrand.RandomState object at 0x118179558>,
#            verbose=0, warm_start=False)

# %%
from IPython.core.display import display, HTML

# This wrapper is because of how I render the notebook to HTML.
# I hide text output by default, so when I *do* want to show it,
# I have to pretend it's HTML output.
display(HTML('<p>Explained variance: {:.0f}%</p>'
             .format(100 * regr.score(X_test, y_test))))
# Out:
# <p>Explained variance: 81%</p>

# %% [markdown]
# The trained model can explain around 80% of the variation in voting outcomes between counties. We can now see which features are most important in explaining this variation,

# %%
# Get the most important features
importances = pd.DataFrame({'importance': regr.feature_importances_},
                           index=list(cols))
importances.sort_values('importance', inplace=True)
importances.iloc[-10:]
# Out:
#                                                 importance
# percent_people_under_18                           0.013466
# percent_people_high_school_graduate               0.016210
# percent_people_black_only                         0.025043
# people_per_square_mile                            0.029189
# building_permits_log                              0.030706
# median_value_owner_occupied_housing_units         0.050702
# percent_people_bachelors                          0.053230
# percent_people_white_only                         0.090893
# percent_people_white_non_hispanic                 0.222278
# percent_housing_units_in_multi_unit_structures    0.255692

# %% [markdown]
# The most important feature is  the percentage of housing units in multi-unit structures. This presumably measures how urban a county is, since apartments presumably count as multi-unit structures.
#
# The second and third most important features are the percentage of people who are white, and white but non-hispanic, respectively. These are presumably well correlated, so I consider them to measure approximately the same thing.
#
# The fourth is the percentage of people with at least a Bachelor's degree, and the fifth is the median house value.
#
# These outcomes seem sensible to me. As extra validation, let's see a few of the least important features. Hopefully, they will seem intuitively like variables that would not provide much information.

# %%
# Get the least important features
importances.iloc[:5]
# Out:
#                                      importance
# percent_firms_pacific_owned            0.000137
# percent_firms_native_mainland_owned    0.000981
# percent_firms_asian_owned              0.001158
# percent_people_native_pacific          0.001189
# people_2010_log                        0.001676

# %% [markdown]
# It seems reasonable to me that two of these features relate to Pacific islander and Hawaiian groups, as these numbers are likely not predictive outside of a few counties where these groups are common.
#
# I am a bit surprised that the county population is in this list, since I showed above that it correlates well with the vote share, but this type of feature is actually present in the dataset in three different forms: two measurements of population in 2010, and another in 2014. It is possible the the other two are adding all of the information that this feature contains, so it gives no extra insight.

# %% [markdown]
# ## Investigate some important features
#
# Finally, let's validate these results by looking directly at how well correlated the most important features are with the vote share.

# %%
show(Scatter(dcfp_scaled,
             'percent_housing_units_in_multi_unit_structures', 'dem_adv',
             xlabel='Share of housing units in multi-unit structures',
             ylabel='Excess democrat vote share',
             title='Correlation of multi-unit accommodation (apartments?) with vote share'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e5bee881-d42f-4ba8-88e0-f75a25bbb449"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("e5bee881-d42f-4ba8-88e0-f75a25bbb449").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e5bee881-d42f-4ba8-88e0-f75a25bbb449");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e5bee881-d42f-4ba8-88e0-f75a25bbb449' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d3bbf0b0-cb0a-4706-8a47-c4cf3f435c2a":{"roots":{"references":[{"attributes":{"location":"top_left","plot":{"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"}},"id":"a2dcaff3-24b1-41d9-9f0b-019c0965a37e","type":"Legend"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"51b19735-098b-4e09-b1c1-ec4bf2ae246a","type":"PanTool"},{"id":"69b12a4a-a9ae-43d6-acaf-d6089950b2eb","type":"WheelZoomTool"},{"id":"fcc45afc-af91-4fd4-97e3-7c2f99724dfe","type":"BoxZoomTool"},{"id":"17dc188c-63d7-4c91-87ab-3d0e6f02050b","type":"SaveTool"},{"id":"e938ab78-502c-4499-9cc0-732a7af9d9cb","type":"ResetTool"},{"id":"61f2d7be-bd20-445e-ae17-8bf5327473fa","type":"HelpTool"}]},"id":"6b9dfe0d-fc87-44d7-984a-f64a9b4cedef","type":"Toolbar"},{"attributes":{"data_source":{"id":"8d859e5d-bc70-4c27-9435-5f5659c8422e","type":"ColumnDataSource"},"glyph":{"id":"6159fd39-2054-4312-bffd-48e2ba9470bf","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"0b612581-5ef8-4b2f-9093-992fad37af67","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"c2a261fb-30a1-4e76-a9c4-ae1f6de1b3d4","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"2b005ec7-d557-4470-b412-9572c9714cab","type":"LinearAxis"}],"renderers":[{"id":"a7e2ee76-c9ae-4244-a6b6-219dba4a09d5","type":"BoxAnnotation"},{"id":"0b612581-5ef8-4b2f-9093-992fad37af67","type":"GlyphRenderer"},{"id":"a2dcaff3-24b1-41d9-9f0b-019c0965a37e","type":"Legend"},{"id":"c2a261fb-30a1-4e76-a9c4-ae1f6de1b3d4","type":"LinearAxis"},{"id":"2b005ec7-d557-4470-b412-9572c9714cab","type":"LinearAxis"},{"id":"0aea54dc-0903-48f6-8a65-2815c46cd3c0","type":"Grid"},{"id":"c69ee931-2c78-4e28-8468-17a8c252b30b","type":"Grid"}],"title":{"id":"9e745f6a-eea0-4b80-977a-335da9995259","type":"Title"},"tool_events":{"id":"86b13cbe-9d7b-4bbe-b17b-2e48eff4d558","type":"ToolEvents"},"toolbar":{"id":"6b9dfe0d-fc87-44d7-984a-f64a9b4cedef","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"06998e28-0299-47e9-8890-27d509170a10","type":"Range1d"},"y_mapper_type":"auto","y_range":{"id":"58cb00d5-c04a-45a6-87d3-e4972d1939c2","type":"Range1d"}},"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"},{"attributes":{"overlay":{"id":"a7e2ee76-c9ae-4244-a6b6-219dba4a09d5","type":"BoxAnnotation"},"plot":{"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"}},"id":"fcc45afc-af91-4fd4-97e3-7c2f99724dfe","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"},"ticker":{"id":"deda6ade-dd77-415e-b709-07b05fde1c55","type":"BasicTicker"}},"id":"0aea54dc-0903-48f6-8a65-2815c46cd3c0","type":"Grid"},{"attributes":{"plot":{"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"}},"id":"61f2d7be-bd20-445e-ae17-8bf5327473fa","type":"HelpTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a7e2ee76-c9ae-4244-a6b6-219dba4a09d5","type":"BoxAnnotation"},{"attributes":{},"id":"8cdf6b00-29df-4cbd-919d-3de9ada1524d","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"},"ticker":{"id":"8cdf6b00-29df-4cbd-919d-3de9ada1524d","type":"BasicTicker"}},"id":"c69ee931-2c78-4e28-8468-17a8c252b30b","type":"Grid"},{"attributes":{"axis_label":"Share of housing units in multi-unit structures","formatter":{"id":"b4454b54-5562-490d-a1d8-5d3086cdd085","type":"BasicTickFormatter"},"plot":{"id":"3d6d1e43-333b-4131-93b8-18cfb948c294","subtype":"Chart","type":"Plot"},"ticker":{"id":"deda6ade-dd77-415e-b709-07b05fde1c55","type":"BasicTicker"}},"id":"c2a261fb-30a1-4e76-a9c4-ae1f6de ...

# %%
show(Scatter(dcfp_scaled, 'percent_people_white_non_hispanic', 'dem_adv',
             xlabel='Share of people white and non-hispanic',
             ylabel='Excess democrat vote share',
             title='Correlation of white ethnicity with vote share'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="361e0627-f1a9-457a-a215-1304ad6a41d3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("361e0627-f1a9-457a-a215-1304ad6a41d3").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("361e0627-f1a9-457a-a215-1304ad6a41d3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '361e0627-f1a9-457a-a215-1304ad6a41d3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7cbded99-ffc1-4cad-a3c1-3ca5dfd7b16e":{"roots":{"references":[{"attributes":{"data_source":{"id":"31ac62ff-842c-4536-9b13-af516963f3e7","type":"ColumnDataSource"},"glyph":{"id":"a056fb89-2372-4e04-88c1-32292b554bd7","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"368c81db-8c19-4543-813d-91ca70a47e85","type":"GlyphRenderer"},{"attributes":{"plot":null,"text":"Correlation of white ethnicity with vote share"},"id":"500302d7-ffcb-4683-b5e4-4a79e9cc623f","type":"Title"},{"attributes":{"plot":{"id":"0298b4c1-5147-4573-a330-b19c18f408c9","subtype":"Chart","type":"Plot"}},"id":"d88aed94-4fa1-4dfb-8405-08a5f7ffc716","type":"SaveTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7788c84b-1aee-497f-b478-c9aabb04ae67","type":"PanTool"},{"id":"31411ba9-09e1-4ba4-9d16-e144f30e76f3","type":"WheelZoomTool"},{"id":"4b00f9b1-4ed7-411d-bab9-9148cb90770b","type":"BoxZoomTool"},{"id":"d88aed94-4fa1-4dfb-8405-08a5f7ffc716","type":"SaveTool"},{"id":"bfd292b3-f570-4cfc-9100-498ff1a26a4b","type":"ResetTool"},{"id":"ea185ece-1549-4e55-b652-893ee97810eb","type":"HelpTool"}]},"id":"21aa7231-08ce-4e88-bdf2-b07acfb4c0c5","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"a056fb89-2372-4e04-88c1-32292b554bd7","type":"Circle"},{"attributes":{"location":"top_left","plot":{"id":"0298b4c1-5147-4573-a330-b19c18f408c9","subtype":"Chart","type":"Plot"}},"id":"994a354c-fd55-4391-93f8-23d949c9dd79","type":"Legend"},{"attributes":{"callback":null,"end":108.14999999999999,"start":-6.450000000000001},"id":"ac77b651-5db3-4626-87e9-362a54ca3196","type":"Range1d"},{"attributes":{"overlay":{"id":"45549488-2d4d-4975-9903-d1f29d6292b7","type":"BoxAnnotation"},"plot":{"id":"0298b4c1-5147-4573-a330-b19c18f408c9","subtype":"Chart","type":"Plot"}},"id":"4b00f9b1-4ed7-411d-bab9-9148cb90770b","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
show(Scatter(dcfp_scaled, 'median_value_owner_occupied_housing_units', 'dem_adv',
             xlabel='Median house value of owner-occupied housing units',
             ylabel='Excess democrat vote share (normalized)',
             title='Correlation of house value with vote share'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="cd9fbc54-070e-4014-967a-76512c1f9192"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("cd9fbc54-070e-4014-967a-76512c1f9192").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cd9fbc54-070e-4014-967a-76512c1f9192");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cd9fbc54-070e-4014-967a-76512c1f9192' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e49ee854-65a6-45f4-a25a-370c8ef73d2f":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"1f501111-0a59-4593-b356-fdb635df8132","type":"Circle"},{"attributes":{"callback":null,"end":1019170.0,"start":-54470.0},"id":"e4a373d2-1e4b-435c-b3f4-fd6e63a81db8","type":"Range1d"},{"attributes":{"data_source":{"id":"24e5c83f-1f7a-476c-a822-697b8e27849f","type":"ColumnDataSource"},"glyph":{"id":"1f501111-0a59-4593-b356-fdb635df8132","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"3d55dbec-a123-45e3-98b7-fc996b256c12","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":1.0676061358576345,"start":-1.0967245247473882},"id":"161ddbb2-9fb8-463f-aafa-e36a999cf1bf","type":"Range1d"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nu ...

# %% [markdown]
# Indeed, it does look like there is some correlation in these quantities, which could help a prediction.
#
# Let's look at some of the least important features, to see if this agrees with our intuition.

# %%
show(Scatter(dcfp_scaled, 'percent_firms_pacific_owned', 'dem_adv',
             xlabel='Percentage of firms owned by Pacific islanders',
             ylabel='Excess democrat vote share (normalized)',
             title='Correlation of Pacific islander firm ownership with vote share'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bc760fb2-62aa-46ed-8eb2-f9b790fdf595"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("bc760fb2-62aa-46ed-8eb2-f9b790fdf595").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc760fb2-62aa-46ed-8eb2-f9b790fdf595");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc760fb2-62aa-46ed-8eb2-f9b790fdf595' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"39f4afce-f268-4d50-9da2-bc4390c36bba":{"roots":{"references":[{"attributes":{},"id":"5e5c670e-ecfb-443f-902d-9f717caac9d5","type":"BasicTickFormatter"},{"attributes":{},"id":"6e5616c6-5ddf-47ed-8d44-13f5cea88f75","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Correlation of Pacific islander firm ownership with vote share"},"id":"a2760a3d-f22e-46b4-9c94-610a691f2c37","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"fcf3e5aa-3f48-4f52-a8dc-eed3e915540d","type":"PanTool"},{"id":"f24727a9-6fd8-4a71-ba35-a7513a7fdfb4","type":"WheelZoomTool"},{"id":"8962ea35-6579-4652-9953-086907d8012d","type":"BoxZoomTool"},{"id":"b150589c-96cd-4095-b683-4a8df0248846","type":"SaveTool"},{"id":"660c9d04-a3b7-4d2b-a646-7fbe82018f00","type":"ResetTool"},{"id":"ba5c7730-9902-474d-954f-55017f31f875","type":"HelpTool"}]},"id":"89114d29-5452-4f19-873b-9b6d62025b92","type":"Toolbar"},{"attributes":{"axis_label":"Percentage of firms owned by Pacific islanders","formatter":{"id":"892682fc-911a-42a1-82dc-f877dc6bba36","type":"BasicTickFormatter"},"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"},"ticker":{"id":"f2be3675-a091-424e-b656-4e4f3e234842","type":"BasicTicker"}},"id":"476b2156-35ac-4ba0-beec-bc896271bd15","type":"LinearAxis"},{"attributes":{"location":"top_left","plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"5b97867c-979a-46a8-a6d4-1190e234001d","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"acf78227-8133-4d57-863e-0739b558b626","type":"BoxAnnotation"},{"attributes":{"callback":null,"end":11.55,"start":-1.05},"id":"cb38c8dc-bd9a-42b9-9081-1ae3b6207783","type":"Range1d"},{"attributes":{"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"fcf3e5aa-3f48-4f52-a8dc-eed3e915540d","type":"PanTool"},{"attributes":{"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"f24727a9-6fd8-4a71-ba35-a7513a7fdfb4","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"acf78227-8133-4d57-863e-0739b558b626","type":"BoxAnnotation"},"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"8962ea35-6579-4652-9953-086907d8012d","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"b150589c-96cd-4095-b683-4a8df0248846","type":"SaveTool"},{"attributes":{"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"660c9d04-a3b7-4d2b-a646-7fbe82018f00","type":"ResetTool"},{"attributes":{"plot":{"id":"1634b757-50a0-4802-bbee-b7c293e03ff8","subtype":"Chart","type":"Plot"}},"id":"ba5c7730-9902-474d-954f-55017f31f875","type":"HelpTool"},{"attributes":{"below":[{"id":"476b2156-35ac-4ba0-beec-bc896271bd15","type":"LinearAxis"}],"css_classes":null,"left":[{"id":"ed820157-3f1f-4d3a-9e9c-1efa1d49c8be","type":"LinearAxis"}],"renderers":[{"id":"acf78227-8133-4d57-863e-0739b558b626","type":"BoxAnnotation"},{"id":"4f534615-90e6-4b74-9c1f-306b8013c02a","type":"GlyphRenderer"},{"id":"5b97867c-979a-46a8-a6d4-1190e234001d","type":"Legend"},{"id":"476b2156-35ac-4ba0-beec-bc896271bd15","type":"LinearAxis"},{"id":"ed820157-3f1f-4d3a-9e9c-1efa1d49c8be","type":"LinearAxis"},{"id":"7c3f9358-379c-439c-bb04-9819b20f5b90","type":"Grid"},{"id":"a359483e-268c-48a4-bc83-e0cfce03f307","type":"Grid"}],"title":{"id":"a2760a3d-f22e-46b4-9c94-610a691f2c37","type":"Title"},"tool_events":{"id":"6e5616c6-5ddf-47ed-8d44-13f5cea88f75","type":"ToolEvents"},"toolbar":{"id":"89114d29-5452-4f19-873b-9b6d62025b92","type":"Toolbar"},"x_mapp ...

# %%
show(Scatter(dcfp_scaled, 'percent_people_native_pacific', 'dem_adv',
             xlabel='Share of people Pacific islanders',
             ylabel='Excess democrat vote share (normalized)',
             title='Correlation of Pacific island ethnicity with vote share'))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b744f4af-2138-4b19-b803-26bcc887131a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b744f4af-2138-4b19-b803-26bcc887131a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b744f4af-2138-4b19-b803-26bcc887131a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b744f4af-2138-4b19-b803-26bcc887131a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0aded8c6-e8be-4048-ac0f-39fa7efb93c5":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a11b3d24-cd49-4abe-ad5c-5349e224080c","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"a11b3d24-cd49-4abe-ad5c-5349e224080c","type":"BoxAnnotation"},"plot":{"id":"89fd3b36-d7bb-4126-b9e1-9f5ec9184676","subtype":"Chart","type":"Plot"}},"id":"3039354c-1852-4881-bed7-b8dcaeefb089","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"89fd3b36-d7bb-4126-b9e1-9f5ec9184676","subtype":"Chart","type":"Plot"}},"id":"778cf54d-a2af-4702-9520-65c20ee8f751","type":"ResetTool"},{"attributes":{"plot":{"id":"89fd3b36-d7bb-4126-b9e1-9f5ec9184676","subtype":"Chart","type":"Plot"}},"id":"7c95812a-29f4-436a-a970-149b38bc4ccc","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"89fd3b36-d7bb-4126-b9e1-9f5ec9184676","subtype":"Chart","type":"Plot"}},"id":"9a45c0cd-7729-4ffd-be37-8637ae0a2713","type":"HelpTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#f22c40"},"line_color":{"value":"#f22c40"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"3c0bd5bb-a0fa-4b2a-ba5d-07f2be117ad3","type":"Circle"},{"attributes":{"data_source":{"id":"0f336bd1-e7b6-4ff0-9c83-434c133aff9d","type":"ColumnDataSource"},"glyph":{"id":"3c0bd5bb-a0fa-4b2a-ba5d-07f2be117ad3","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"dbafe7d2-27c4-4468-8869-b7aff5d2f71c","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...

# %% [markdown]
# Indeed, for these variables it seems like, except for a few counties, the range of values is low, and not very well correlated.
#
# By the way, if you are thinking at this point, "Boy, I wish the author had clipped the x-axis to exclude those outliers, so I can see the distribution of the main body", then you're thinking in the wrong century: there's a zoom tool on that figure, go do it yourself! I don't want to bias your interpretation by putting my opinions on the axis limits.

# %% [markdown]
# ## Conclusion
#
# I wanted to do this analysis because I was curious about how much changes in demographics like income, age, population density and education could explain changes in voting patterns. For example, I think it's interesting that the outcome of a vote can change as the percentage of older people increases, even if the typical political belief of a person in any given age group stays constant. Although seemingly obvious, this isn't an observation that I see made very often, and I think it might sometimes be able to explain some trends better than more ephemeral and hard-to-measure societal shifts.

# %% [markdown]
# ## Acknowledgments
#
# Thanks to,
#
# - Jake Vanderplas for writing the plugin allowing me to host this notebook on my blog
# - Michael W. Kearney for gathering the voting data
# - The US Census Bureau, for gathering and providing demograpic data
# - Toby Searle for providing common sense

# %% [markdown]
# ## Links
#
# - Find this notebook [here](https://gist.github.com/eddiejessup/0e769a6d35434df80d972b857ecdfbd9)
